# %%
dataloc = '/Users/dwatkin2/Documents/research/data/usnic/weekly_shapefiles/'
year = 2020

# %% [markdown]
# Potential things to add here
# * MIZ extent
# * Landfast ice extent
# * Sea ice extent

# %% [markdown]
# Before taking too long on this -- need to
